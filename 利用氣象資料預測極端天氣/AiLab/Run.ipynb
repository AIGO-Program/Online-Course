# %% [markdown]
# ## Environment Setup

# %%
import torch
import pandas as pd
import numpy as np
from sklearn import preprocessing
import torch.utils.data as Data
from datetime import datetime, timedelta

from radam import RAdam
import data_utils

# %%
# Check if PyTorch can use GPU in this environment
print('Torch', torch.__version__, 'CUDA', torch.version.cuda)
print('Device:', torch.device('cuda:0'))
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
if device=='cuda':
    torch.cuda.get_device_name(0)
# Out:
# Torch 1.4.0 CUDA 10.1
# Device: cuda:0

# %%
# Define random seed for torch
torch.manual_seed(7) # cpu
torch.cuda.manual_seed(7) #gpu

# %% [markdown]
# ## Parameter Setting

# %%
STATION_ID = '001'

# %%
"""
Purpose: Merge several one-month train/test data into single file
"""
extension = 'csv'

data_utils.merge_files(STATION_ID,'data/forecast_data/train',STATION_ID+'_train.csv',extension)
data_utils.merge_files(STATION_ID,'data/forecast_data/test',STATION_ID+'_test.csv',extension)
# Out:
# Number of files: 9
# Number of files: 3

# %%
"""
Load csv data to dataframe
"""
input_train_data = pd.read_csv('data/forecast_data/train/{}_train.csv'.format(STATION_ID), error_bad_lines=False)
input_test_data = pd.read_csv('data/forecast_data/test/{}_test.csv'.format(STATION_ID), error_bad_lines=False)

observation_data = pd.read_csv('data/observation_data/{}.csv'.format(STATION_ID), error_bad_lines=False)

print('input_train_data Shape: ', input_train_data.shape)
print('input_test_data Shape: ', input_test_data.shape)

input_train_data.head()
# Out:
# input_train_data Shape: (102363, 33)
# input_test_data Shape: (33968, 33)
#    stno  yyyymmddhh  year  month  day  hour   PS01    PS02  TX01  RH01  \
# 0     1  2017010120  2017      1    1    20  646.3  3192.7   4.9    15
# 1     1  2017010121  2017      1    1    21  646.5  3193.5   5.4    14
# 2     1  2017010122  2017      1    1    22  646.7  3192.7   5.1    14
# 3     1  2017010123  2017      1    1    23  646.6  3188.9   5.6    14
# 4     1  2017010124  2017      1    1    24  646.5  3190.3   5.2    14
#
#      ...     DSWRF  HCDC      LCDC      MCDC          PRES          PRMSL  \
# 0    ...       0.0   0.0  0.000000  0.000000  36553.144444  102715.444444
# 1    ...       0.0   0.0  5.333333  1.333333  36538.138889  102515.333333
# 2    ...       0.0   0.0  6.666667  2.111111  36524.805556  102486.222222
# 3    ...       0.0   0.0  3.777778  1.444444  36520.372222  102456.888889
# 4    ...       0.0   0.0  1.777778  0.222222  36531.083333  102467.888889
#
#           RH         TMP      UGRD      VGRD
# 0  90.333333  281.022222 -1.908889  0.995556
# 1  56.677778  278.113333  1.588889 -0.678889
# 2  50.922222  278.266667  0.513333 -0.097778
# 3  45.311111  278.201111  0.988889 -0.543333
# 4  40.944444  278.458889  0.711111 -0.532222
#
# [5 rows x 33 columns]

# %%
"""
Clean the data
  -9991 儀器故障待修無資料,
  -9996 資料累計於後,
  -9997 因不明原因或故障等因素無資料,
  -9998 雨跡(Trace),
  -9999 未觀測而無資料
"""
input_train_data = input_train_data[input_train_data.TX01>-9991]
input_test_data = input_test_data[input_test_data.TX01>-9991]

print('input_train_data Shape: ' + str(input_train_data.shape))
print('input_test_data Shape: ' + str(input_test_data.shape))
# Out:
# input_train_data Shape: (100729, 33)
# input_test_data Shape: (33968, 33)

# %% [markdown]
# 新增時間欄位
#
# 由於時間有週期性，因此用 sin 跟 cos 來表示
#
# 參考：https://ianlondon.github.io/blog/encoding-cyclical-features-24hour-time/

# %%
hours_in_day = 24

input_train_data_hour_in_a_day_radian = 2*np.pi*input_train_data.hour/hours_in_day
input_train_data['sin_time'] = np.sin(input_train_data_hour_in_a_day_radian)
input_train_data['cos_time'] = np.cos(input_train_data_hour_in_a_day_radian)

input_test_data_hour_in_a_day_radian = 2*np.pi*input_test_data.hour/hours_in_day
input_test_data['sin_time'] = np.sin(input_test_data_hour_in_a_day_radian)
input_test_data['cos_time'] = np.cos(input_test_data_hour_in_a_day_radian)

months_in_year = 12
input_train_data_month_in_a_year_radian = 2*np.pi*input_train_data.month/months_in_year
input_train_data['sin_month_time'] = np.sin(input_train_data_month_in_a_year_radian)
input_train_data['cos_month_time'] = np.cos(input_train_data_month_in_a_year_radian)

input_test_data_month_in_a_year_radian = 2*np.pi*input_test_data.month/months_in_year
input_test_data['sin_month_time'] = np.sin(input_test_data_month_in_a_year_radian)
input_test_data['cos_month_time'] = np.cos(input_test_data_month_in_a_year_radian)

input_test_data.head()
# Out:
#    stno  yyyymmddhh  year  month  day  hour   PS01    PS02  TX01  RH01  \
# 0     1  2017100108  2017     10    1     8  647.8  3206.0  11.0    70
# 1     1  2017100109  2017     10    1     9  648.3  3210.7  13.0    62
# 2     1  2017100110  2017     10    1    10  648.3  3209.0  14.6    58
# 3     1  2017100111  2017     10    1    11  647.9  3201.5  16.6    54
# 4     1  2017100112  2017     10    1    12  647.2  3191.0  17.0    54
#
#        ...                PRES          PRMSL         RH         TMP  \
# 0      ...        73214.455556  102470.333333  71.900000  289.585556
# 1      ...        36617.755556  102443.555556  78.000000  287.600000
# 2      ...        36610.172222  102401.888889  77.611111  287.945556
# 3      ...        36620.750000  102427.222222  83.644444  287.871111
# 4      ...        36619.077778  102413.444444  89.566667  287.857778
#
#        UGRD      VGRD      sin_time  cos_time  sin_month_time cos_month_time
# 0 -1.446667  0.693333  8.660254e-01 -0.500000       -0.866025            0.5
# 1 -0.601111  0.803333  7.071068e-01 -0.707107       -0.866025            0.5
# 2 -0.185556  0.483333  5.000000e-01 -0.866025       -0.866025            0.5
# 3  0.108889 -0.243333  2.588190e-01 -0.965926       -0.866025            0.5
# 4 -0.034444 -0.592222  1.224647e-16 -1.000000       -0.866025            0.5
#
# [5 rows x 37 columns]

# %% [markdown]
# 產生時雨量
# 將前後兩小時的累積雨量相減

# %%
start_times = input_train_data['start_time'].unique()
str2date = {}
for start_time in start_times:
    start_time_date = datetime.strptime(start_time, '%Y-%m-%d %H:%M:%S %Z')
    start_time_date_prev = start_time_date + timedelta(hours=-1)
    str2date[start_time] = "{} UTC".format(start_time_date_prev)

input_train_data['start_time_prev'] = input_train_data.apply(lambda x: str2date[x['start_time']] , axis=1)

start_times = input_test_data['start_time'].unique()
str2date = {}
for start_time in start_times:
    start_time_date = datetime.strptime(start_time, '%Y-%m-%d %H:%M:%S %Z')
    start_time_date_prev = start_time_date + timedelta(hours=-1)
    str2date[start_time] = "{} UTC".format(start_time_date_prev)
input_test_data['start_time_prev'] = input_test_data.apply(lambda x: str2date[x['start_time']] , axis=1)

# %%
df_byhour_prev = input_train_data[['start_time','issue_time','APCP']].copy()
df_byhour_prev.rename(columns={'start_time':'start_time_prev','APCP':'APCP_prev'},inplace=True)
df_byhour2 = pd.merge(input_train_data, df_byhour_prev, how='left', on=['start_time_prev','issue_time'])

df_byhour2['APCP_diff'] = df_byhour2['APCP'] - df_byhour2['APCP_prev']
input_train_data = df_byhour2

df_byhour_prev = input_test_data[['start_time','issue_time','APCP']].copy()
df_byhour_prev.rename(columns={'start_time':'start_time_prev','APCP':'APCP_prev'},inplace=True)
df_byhour2 = pd.merge(input_test_data, df_byhour_prev, how='left', on=['start_time_prev','issue_time'])

df_byhour2['APCP_diff'] = df_byhour2['APCP'] - df_byhour2['APCP_prev']
input_test_data = df_byhour2
# Out:
# C:\Users\jason.hsu\.conda\envs\aigo-weather\lib\site-packages\pandas\core\frame.py:3778: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
input_train_data['APCP_diff'] = input_train_data.apply(lambda row: data_utils.remove_null_column(row, 'APCP_diff'), axis=1)
input_test_data['APCP_diff'] = input_test_data.apply(lambda row: data_utils.remove_null_column(row, 'APCP_diff'), axis=1)

# %%
input_train_data['tmp_diff'] = input_train_data['TX01'] - (input_train_data['TMP']-273.15)
input_test_data['tmp_diff'] = input_test_data['TX01'] - (input_test_data['TMP']-273.15)

# %%
input_test_data = input_test_data.sort_values(['yyyymmddhh','number_of_hour'], ascending=[True,True])
input_test_data.head()
# Out:
#    stno  yyyymmddhh  year  month  day  hour   PS01    PS02  TX01  RH01  \
# 0     1  2017100108  2017     10    1     8  647.8  3206.0  11.0    70
# 1     1  2017100109  2017     10    1     9  648.3  3210.7  13.0    62
# 2     1  2017100110  2017     10    1    10  648.3  3209.0  14.6    58
# 3     1  2017100111  2017     10    1    11  647.9  3201.5  16.6    54
# 4     1  2017100112  2017     10    1    12  647.2  3191.0  17.0    54
#
#      ...         UGRD      VGRD      sin_time  cos_time  sin_month_time  \
# 0    ...    -1.446667  0.693333  8.660254e-01 -0.500000       -0.866025
# 1    ...    -0.601111  0.803333  7.071068e-01 -0.707107       -0.866025
# 2    ...    -0.185556  0.483333  5.000000e-01 -0.866025       -0.866025
# 3    ...     0.108889 -0.243333  2.588190e-01 -0.965926       -0.866025
# 4    ...    -0.034444 -0.592222  1.224647e-16 -1.000000       -0.866025
#
#    cos_month_time          start_time_prev  APCP_prev  APCP_diff  tmp_diff
# 0             0.5  2017-09-30 23:00:00 UTC        NaN   0.000000 -5.435556
# 1             0.5  2017-10-01 00:00:00 UTC   0.000000   0.000000 -1.450000
# 2             0.5  2017-10-01 01:00:00 UTC   0.000000   0.000000 -0.195556
# 3             0.5  2017-10-01 02:00:00 UTC   0.000000   0.004111  1.878889
# 4             0.5  2017-10-01 03:00:00 UTC   0.004111   0.163667  2.292222
#
# [5 rows x 41 columns]

# %% [markdown]
# Prepare Data

# %% [markdown]
# Clean the data
#
# *  -9991 儀器故障待修無資料,
# *  -9996 資料累計於後,
# *  -9997 因不明原因或故障等因素無資料,
# *  -9998 雨跡(Trace),
# *  -9999 未觀測而無資料
#
# 資料狀況
# *  CD11 太多 -9999
# *  SS01 -9999 有7706筆
# *  SS02 -9999/-9997 有662筆
# *  PP01 -9999/-9997 有581筆
#
# 整理資料
# *  TX01：清除
# *  RH01：→100
# *  PP01：→0
# *  PS01：→643.463(平均值)
# *  PS02：→3159.6909(平均值)
# *  WD01：→0
# *  WD02：→0

# %%
observation_data.head()
# Out:
#    stno  yyyymmddhh  year  month  day  hour   PS01    PS02  TX01  TX04  \
# 0     1  2017010101  2017      1    1     1  646.3  3192.7   3.4 -9999
# 1     1  2017010102  2017      1    1     2  646.1  3190.1   3.3 -9999
# 2     1  2017010103  2017      1    1     3  645.9  3187.0   3.1 -9999
# 3     1  2017010104  2017      1    1     4  645.6  3184.8   3.2 -9999
# 4     1  2017010105  2017      1    1     5  645.8  3190.2   3.3 -9999
#
#     ...    ST06  ST07  ST08  ST09  ST10  ST11  ST12  PS11  RH06    UV01
# 0   ...   -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999.0
# 1   ...   -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999.0
# 2   ...   -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999.0
# 3   ...   -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999.0
# 4   ...   -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999.0
#
# [5 rows x 55 columns]

# %%
"""
Clean the data
  -9991 儀器故障待修無資料,
  -9996 資料累計於後,
  -9997 因不明原因或故障等因素無資料,
  -9998 雨跡(Trace),
  -9999 未觀測而無資料
"""
observation_data['observation_RH01'] = observation_data.apply(lambda row: data_utils.arrange_abnormal_data(row,'RH01',100), axis=1)
observation_data['observation_PP01'] = observation_data.apply(lambda row: data_utils.arrange_abnormal_data(row,'PP01',0), axis=1)
observation_data['observation_PS01'] = observation_data.apply(lambda row: data_utils.arrange_abnormal_data(row,'PS01',643.463), axis=1)
observation_data['observation_PS02'] = observation_data.apply(lambda row: data_utils.arrange_abnormal_data(row,'PS02',3159.6909), axis=1)
observation_data['observation_WD01'] = observation_data.apply(lambda row: data_utils.arrange_abnormal_data(row,'WD01',0), axis=1)
observation_data['observation_WD02'] = observation_data.apply(lambda row: data_utils.arrange_abnormal_data(row,'WD02',0), axis=1)

# %% [markdown]
# 新增時間欄位
#
# 由於時間有週期性，因此用 sin 跟 cos 來表示

# %%
seconds_in_day = 24
months_in_year = 12

observation_data_hour_in_a_day_radian = 2*np.pi*observation_data.hour/hours_in_day
observation_data['observation_sin_time'] = np.sin(observation_data_hour_in_a_day_radian)
observation_data['observation_cos_time'] = np.cos(observation_data_hour_in_a_day_radian)

observation_data_month_in_a_year_radian = 2*np.pi*observation_data.month/months_in_year
observation_data['observation_data_sin_month_time'] = np.sin(observation_data_month_in_a_year_radian)
observation_data['observation_data_cos_month_time'] = np.cos(observation_data_month_in_a_year_radian)

# %%
observation_data.head()
# Out:
#    stno  yyyymmddhh  year  month  day  hour   PS01    PS02  TX01  TX04  \
# 0     1  2017010101  2017      1    1     1  646.3  3192.7   3.4 -9999
# 1     1  2017010102  2017      1    1     2  646.1  3190.1   3.3 -9999
# 2     1  2017010103  2017      1    1     3  645.9  3187.0   3.1 -9999
# 3     1  2017010104  2017      1    1     4  645.6  3184.8   3.2 -9999
# 4     1  2017010105  2017      1    1     5  645.8  3190.2   3.3 -9999
#
#                 ...                 observation_RH01  observation_PP01  \
# 0               ...                             15.0               0.0
# 1               ...                             15.0               0.0
# 2               ...                             15.0               0.0
# 3               ...                             15.0               0.0
# 4               ...                             15.0               0.0
#
#    observation_PS01  observation_PS02  observation_WD01  observation_WD02  \
# 0             646.3            3192.7               5.3             340.0
# 1             646.1            3190.1               4.4             320.0
# 2             645.9            3187.0               4.5             320.0
# 3             645.6            3184.8               4.8             330.0
# 4             645.8            3190.2               6.1             340.0
#
#    observation_sin_time  observation_cos_time  \
# 0              0.258819              0.965926
# 1              0.500000              0.866025
# 2              0.707107              0.707107
# 3              0.866025              0.500000
# 4              0.965926              0.258819
#
#    observation_data_sin_month_time  observation_data_cos_month_time
# 0                              0.5                         0.866025
# 1                              0.5                         0.866025
# 2                              0.5                         0.866025
# 3                              0.5                         0.866025
# 4                              0.5                         0.866025
#
# [5 rows x 65 columns]

# %%
input_train_data.head()
# Out:
#    stno  yyyymmddhh  year  month  day  hour   PS01    PS02  TX01  RH01  \
# 0     1  2017010120  2017      1    1    20  646.3  3192.7   4.9    15
# 1     1  2017010121  2017      1    1    21  646.5  3193.5   5.4    14
# 2     1  2017010122  2017      1    1    22  646.7  3192.7   5.1    14
# 3     1  2017010123  2017      1    1    23  646.6  3188.9   5.6    14
# 4     1  2017010124  2017      1    1    24  646.5  3190.3   5.2    14
#
#      ...         UGRD      VGRD      sin_time  cos_time  sin_month_time  \
# 0    ...    -1.908889  0.995556 -8.660254e-01  0.500000             0.5
# 1    ...     1.588889 -0.678889 -7.071068e-01  0.707107             0.5
# 2    ...     0.513333 -0.097778 -5.000000e-01  0.866025             0.5
# 3    ...     0.988889 -0.543333 -2.588190e-01  0.965926             0.5
# 4    ...     0.711111 -0.532222 -2.449294e-16  1.000000             0.5
#
#    cos_month_time          start_time_prev  APCP_prev  APCP_diff  tmp_diff
# 0        0.866025  2017-01-01 11:00:00 UTC        NaN        0.0 -2.972222
# 1        0.866025  2017-01-01 12:00:00 UTC        0.0        0.0  0.436667
# 2        0.866025  2017-01-01 13:00:00 UTC        0.0        0.0 -0.016667
# 3        0.866025  2017-01-01 14:00:00 UTC        0.0        0.0  0.548889
# 4        0.866025  2017-01-01 15:00:00 UTC        0.0        0.0 -0.108889
#
# [5 rows x 41 columns]

# %% [markdown]
# 準備資料
#
# 將觀測資料的指定時間區段納入考量

# %%
TIME_SHIFT = 120+193
observation_data['shifted_start_time'] = observation_data.apply(lambda row: data_utils.generate_time_shift_columns(row,TIME_SHIFT), axis=1)
observation_data.rename(columns={'yyyymmddhh': 'observation_yyyymmddhh',
'TX01': 'observation_TX01','RH01': 'unused_RH01',
'PP01': 'unused_PP01','WD01': 'unused_WD01',
'WD02': 'unused_WD02','PS01': 'unused_PS01',
'PS02': 'unused_PS02','CD11': 'observation_CD11',
'SS01': 'observation_SS01','SS02': 'observation_SS02',
}, inplace=True)

observation_data.head()
# Out:
#    stno  observation_yyyymmddhh  year  month  day  hour  unused_PS01  \
# 0     1              2017010101  2017      1    1     1        646.3
# 1     1              2017010102  2017      1    1     2        646.1
# 2     1              2017010103  2017      1    1     3        645.9
# 3     1              2017010104  2017      1    1     4        645.6
# 4     1              2017010105  2017      1    1     5        645.8
#
#    unused_PS02  observation_TX01  TX04           ...             \
# 0       3192.7               3.4 -9999           ...
# 1       3190.1               3.3 -9999           ...
# 2       3187.0               3.1 -9999           ...
# 3       3184.8               3.2 -9999           ...
# 4       3190.2               3.3 -9999           ...
#
#    observation_PP01  observation_PS01  observation_PS02  observation_WD01  \
# 0               0.0             646.3            3192.7               5.3
# 1               0.0             646.1            3190.1               4.4
# 2               0.0             645.9            3187.0               4.5
# 3               0.0             645.6            3184.8               4.8
# 4               0.0             645.8            3190.2               6.1
#
#    observation_WD02  observation_sin_time  observation_cos_time  \
# 0             340.0              0.258819              0.965926
# 1             320.0              0.500000              0.866025
# 2             320.0              0.707107              0.707107
# 3             330.0              0.866025              0.500000
# 4             340.0              0.965926              0.258819
#
#    observation_data_sin_month_time  observation_data_cos_month_time  \
# 0                              0.5                         0.866025
# 1                              0.5                         0.866025
# 2                              0.5                         0.866025
# 3                              0.5                         0.866025
# 4                              0.5                         0.866025
#
#         shifted_start_time
# 0  2016-12-19 00:00:00 UTC
# 1  2016-12-19 01:00:00 UTC
# 2  2016-12-19 02:00:00 UTC
# 3  2016-12-19 03:00:00 UTC
# 4  2016-12-19 04:00:00 UTC
#
# [5 rows x 66 columns]

# %%
input_train_data['shifted_start_time'] = input_train_data['start_time']
input_test_data['shifted_start_time'] = input_test_data['start_time']

input_train_data2 = data_utils.join(input_train_data,observation_data,'input_train_data2.csv',False)
input_test_data2 = data_utils.join(input_test_data,observation_data,'input_test_data2.csv',False)

input_train_data2.head()
# Out:
#    stno_x  yyyymmddhh  year_x  month_x  day_x  hour_x   PS01    PS02  TX01  \
# 0       1  2017010120    2017        1      1      20  646.3  3192.7   4.9
# 1       1  2017010121    2017        1      1      21  646.5  3193.5   5.4
# 2       1  2017010122    2017        1      1      22  646.7  3192.7   5.1
# 3       1  2017010123    2017        1      1      23  646.6  3188.9   5.6
# 4       1  2017010124    2017        1      1      24  646.5  3190.3   5.2
#
#    RH01               ...                observation_RH01  observation_PP01  \
# 0    15               ...                           100.0               0.5
# 1    14               ...                            98.0               0.0
# 2    14               ...                            98.0               0.0
# 3    14               ...                            96.0               0.0
# 4    14               ...                            98.0               0.0
#
#    observation_PS01  observation_PS02  observation_WD01  observation_WD02  \
# 0             639.5            3120.5               5.4             300.0
# 1             639.6            3121.8               6.8             350.0
# 2             639.2            3116.7               6.8             340.0
# 3             639.6            3123.1               8.5             340.0
# 4             640.0            3130.2               6.2             340.0
#
#    observation_sin_time  observation_cos_time  \
# 0             -0.258819             -0.965926
# 1             -0.500000             -0.866025
# 2             -0.707107             -0.707107
# 3             -0.866025             -0.500000
# 4             -0.965926             -0.258819
#
#    observation_data_sin_month_time observation_data_cos_month_time
# 0                              0.5                        0.866025
# 1                              0.5                        0.866025
# 2                              0.5                        0.866025
# 3                              0.5                        0.866025
# 4                              0.5                        0.866025
#
# [5 rows x 107 columns]

# %% [markdown]
# Input Normalization

# %%
input_train_data2 = input_train_data
input_test_data2 = input_test_data

# %%
# %%time
input_forecast_column_names = ['PRMSL','PRES','TMP','RH','UGRD','VGRD','APCP_diff','LCDC','MCDC','HCDC','DSWRF','sin_time',
                               'cos_time','sin_month_time','cos_month_time']
input_observation_column_names = ['observation_TX01','observation_RH01','observation_PP01','observation_PS01',
        'observation_PS02','observation_WD01','observation_WD02','observation_sin_time','observation_cos_time',
        'observation_data_sin_month_time','observation_data_cos_month_time']
column_names = input_forecast_column_names
output_column_names = ['tmp_diff']
group_column_name = ['issue_time']
all_column_names = column_names + output_column_names + group_column_name + ['original_TMP']

input_train_data2['original_TMP'] = input_train_data2['TMP']
input_test_data2['original_TMP'] = input_test_data2['TMP']

NORMALIZE_FLAG = True
SCALAR_TYPE = 1
COLUMNS_TO_NORMALIZE = ['PRMSL','PRES','TMP','RH','UGRD','VGRD','APCP_diff','LCDC','MCDC','HCDC','DSWRF']

train_df = input_train_data2[all_column_names].copy()
test_df = input_test_data2[all_column_names].copy()

input_train_data_mean = train_df.mean()
input_train_data_std = train_df.std()

# Create scaler for normalization
if SCALAR_TYPE == 0:
    scaler = preprocessing.MinMaxScaler()
elif SCALAR_TYPE == 1:
    scaler = preprocessing.StandardScaler()

if NORMALIZE_FLAG:
    # Scale preprocessing only apply to the specified columns
    train_df[COLUMNS_TO_NORMALIZE] = scaler.fit_transform(train_df[COLUMNS_TO_NORMALIZE])

    train_normalized = train_df.values
else:
    train_normalized = train_df.values
    test_normalized = test_df.values
# Out:
# C:\Users\jason.hsu\.conda\envs\aigo-weather\lib\site-packages\ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\jason.hsu\.conda\envs\aigo-weather\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# Wall time: 5min 37s

# %% [markdown]
# Test dataset's head info (Before Normalization)

# %%
test_df.head()
# Out:
#            PRMSL          PRES         TMP         RH      UGRD      VGRD  \
# 0  102470.333333  73214.455556  289.585556  71.900000 -1.446667  0.693333
# 1  102443.555556  36617.755556  287.600000  78.000000 -0.601111  0.803333
# 2  102401.888889  36610.172222  287.945556  77.611111 -0.185556  0.483333
# 3  102427.222222  36620.750000  287.871111  83.644444  0.108889 -0.243333
# 4  102413.444444  36619.077778  287.857778  89.566667 -0.034444 -0.592222
#
#    APCP_diff       LCDC      MCDC       HCDC       DSWRF      sin_time  \
# 0   0.000000   0.000000  0.000000   0.000000    0.000000  8.660254e-01
# 1   0.000000   0.000000  0.111111  28.000000  683.722222  7.071068e-01
# 2   0.000000   4.933333  0.000000  25.888889  860.633333  5.000000e-01
# 3   0.004111  15.877778  3.000000  26.222222  886.111111  2.588190e-01
# 4   0.163667  20.866667  8.666667  41.888889  776.222222  1.224647e-16
#
#    cos_time  sin_month_time  cos_month_time  tmp_diff  \
# 0 -0.500000       -0.866025             0.5 -5.435556
# 1 -0.707107       -0.866025             0.5 -1.450000
# 2 -0.866025       -0.866025             0.5 -0.195556
# 3 -0.965926       -0.866025             0.5  1.878889
# 4 -1.000000       -0.866025             0.5  2.292222
#
#                 issue_time  original_TMP
# 0  2017-10-01 00:00:00 UTC    289.585556
# 1  2017-10-01 00:00:00 UTC    287.600000
# 2  2017-10-01 00:00:00 UTC    287.945556
# 3  2017-10-01 00:00:00 UTC    287.871111
# 4  2017-10-01 00:00:00 UTC    287.857778

# %%
print(input_train_data_mean)
# Out:
# PRMSL             102149.635732
# PRES               36494.089692
# TMP                  282.461429
# RH                    78.160661
# UGRD                   1.908172
# VGRD                   0.821651
# APCP_diff              0.667071
# LCDC                  15.746791
# MCDC                  16.963122
# HCDC                  38.587584
# DSWRF                240.494503
# sin_time               0.000093
# cos_time              -0.000005
# sin_month_time         0.128990
# cos_month_time        -0.256872
# tmp_diff              -4.222787
# original_TMP         282.461429
# dtype: float64

# %%
print(input_train_data_std)
# Out:
# PRMSL              347.412803
# PRES              1540.242015
# TMP                  4.134049
# RH                  17.057335
# UGRD                 2.943750
# VGRD                 2.014284
# APCP_diff            2.622685
# LCDC                18.570541
# MCDC                25.130392
# HCDC                38.982537
# DSWRF              325.711011
# sin_time             0.708008
# cos_time             0.706212
# sin_month_time       0.744201
# cos_month_time       0.602952
# tmp_diff             2.467783
# original_TMP         4.134049
# dtype: float64

# %%
# Apply the training data's mean and std to normalize testing data
if SCALAR_TYPE == 1:
    for column_name in COLUMNS_TO_NORMALIZE:
        index = all_column_names.index(column_name)

        test_df[column_name] = test_df.apply(lambda row: data_utils.standard_normalization(row,column_name,index,
           input_train_data_mean,input_train_data_std), axis=1)
# Out:
# C:\Users\jason.hsu\.conda\envs\aigo-weather\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %% [markdown]
# Test dataset's head info (After Normalization)

# %%
test_df.head()
# Out:
#       PRMSL       PRES       TMP        RH      UGRD      VGRD  APCP_diff  \
# 0  0.923102  23.840647  1.723281 -0.367036 -1.139648 -0.063704  -0.254347
# 1  0.846025   0.080290  1.242987 -0.009419 -0.852410 -0.009094  -0.254347
# 2  0.726091   0.075366  1.326575 -0.032218 -0.711245 -0.167959  -0.254347
# 3  0.799011   0.082234  1.308567  0.321491 -0.611221 -0.528716  -0.252779
# 4  0.759352   0.081148  1.305342  0.668686 -0.659912 -0.701924  -0.191942
#
#        LCDC      MCDC      HCDC     DSWRF      sin_time  cos_time  \
# 0 -0.847945 -0.675004 -0.989868 -0.738368  8.660254e-01 -0.500000
# 1 -0.847945 -0.670583 -0.271598  1.360801  7.071068e-01 -0.707107
# 2 -0.582291 -0.675004 -0.325753  1.903954  5.000000e-01 -0.866025
# 3  0.007053 -0.555627 -0.317203  1.982176  2.588190e-01 -0.965926
# 4  0.275699 -0.330136  0.084687  1.644795  1.224647e-16 -1.000000
#
#    sin_month_time  cos_month_time  tmp_diff               issue_time  \
# 0       -0.866025             0.5 -5.435556  2017-10-01 00:00:00 UTC
# 1       -0.866025             0.5 -1.450000  2017-10-01 00:00:00 UTC
# 2       -0.866025             0.5 -0.195556  2017-10-01 00:00:00 UTC
# 3       -0.866025             0.5  1.878889  2017-10-01 00:00:00 UTC
# 4       -0.866025             0.5  2.292222  2017-10-01 00:00:00 UTC
#
#    original_TMP
# 0    289.585556
# 1    287.600000
# 2    287.945556
# 3    287.871111
# 4    287.857778

# %% [markdown]
# 用 issue_time 來做 group by 以產生每組 sequence data

# %%
train_groupdf = train_df.groupby("issue_time")
test_groupdf = test_df.groupby("issue_time")

# %%
train_issue_times = input_train_data['issue_time'].unique()
test_issue_times = input_test_data['issue_time'].unique()

# %%
train_input_keys = train_groupdf.groups.keys()
train_inputs,train_outputs = data_utils.get_io_data(train_input_keys,train_groupdf,column_names+['original_TMP'],output_column_names,False)

test_input_keys = test_groupdf.groups.keys()
test_inputs,test_outputs = data_utils.get_io_data(test_input_keys,test_groupdf,column_names+['original_TMP'],output_column_names,False)

# %% [markdown]
# ## LSTM
# [Ref](https://morvanzhou.github.io/tutorials/machine-learning/torch/4-02-RNN-classification/)
#
# [Ref2](https://blog.csdn.net/qq_26657001/article/details/87892833)

# %%
# Hyper Parameters
TIME_STEP = 193      # rnn time step
INPUT_SIZE = len(column_names)      # rnn input size

# %%
class LSTMRNN(torch.nn.Module):
    def __init__(self, input_size, hidden_size, num_of_layers):
        super(LSTMRNN, self).__init__()

        self.num_of_layers = num_of_layers
        self.hidden_size = hidden_size
        self.rnn = torch.nn.LSTM(
            input_size=input_size,
            hidden_size=hidden_size,
            num_layers=num_of_layers, 
            batch_first=True,
            dropout=0.2,
        )
        self.out = torch.nn.Linear(hidden_size, 1)

    def init_hidden(self, batch_size):
        h0=torch.randn(self.num_of_layers,batch_size,self.hidden_size)
        c0=torch.randn(self.num_of_layers,batch_size,self.hidden_size)
        return (h0,c0)
    
    def forward(self, x, h_state):
        r_out, h_state = self.rnn(x, h_state)
        r_out = r_out.contiguous().view(-1, self.hidden_size)
        outs = self.out(r_out)
        outs = outs.view(-1, TIME_STEP, 1)
        return outs, h_state

# %% [markdown]
# Data Preparation

# %%
HIDDEN_SIZE = 128
NUM_OF_LAYERS = 3
HIDDEN_SIZE_2 = 32
NUM_OF_LAYERS_2 = 1
LR = 0.001
h_state = None
BATCH_SIZE = 64
TEST_BATCH_SIZE = 64
INPUT_SIZE = len(input_forecast_column_names)
batch_decoder_x_len = len(input_forecast_column_names)
EPOCHS = 36
MAX_STEP = 100

rnn = LSTMRNN(INPUT_SIZE,HIDDEN_SIZE,NUM_OF_LAYERS)

# Create optimizer and loss function
optimizer = RAdam(rnn.parameters(), lr=LR)
loss_func = torch.nn.MSELoss()

# %%
# Convert (batch_size, seq_len, input_size) to (seq_len, batch_size, input_size)
# Convert numpy to tensor
train_input_tensors = torch.FloatTensor(train_inputs)
test_input_tensors = torch.FloatTensor(test_inputs)

# 2 sequences (to match the batch size) of length 6 (for the 6h into the future)
# Convert numpy to tensor
train_output_tensors = torch.FloatTensor(train_outputs)
test_output_tensors = torch.FloatTensor(test_outputs)

# 先轉換 torch 能識別的 Dataset
train_dataset = Data.TensorDataset(train_input_tensors,train_output_tensors)
test_dataset = Data.TensorDataset(test_input_tensors,test_output_tensors)

# After creating the workers, each worker has an independent seed that is initialized to the curent random seed + the id of the worker
def worker_init_fn(worker_id):
    np.random.seed(7)

# 把 dataset 放入 DataLoader
train_dataloader = Data.DataLoader(
    dataset=train_dataset, 
    batch_size=BATCH_SIZE, 
    shuffle=True,           # 要不要打亂數據
    worker_init_fn=worker_init_fn   # random seed
)

test_dataloader = Data.DataLoader(
    dataset=test_dataset,
    batch_size=TEST_BATCH_SIZE,
    shuffle=False,
    worker_init_fn=worker_init_fn
)

# %%
# %%time
for epoch in range(EPOCHS):
    for step, (batch_full_x, batch_y) in enumerate(train_dataloader):  # 每一步 loader 釋放一小批數據來學習
        rnn.train()
        optimizer.zero_grad()  # clear gradients for this training step

        # (batch, seq_len, input_size)
        batch_x = batch_full_x[:,:,:batch_decoder_x_len]

        if step > MAX_STEP:
            break

        # If the last batch from DataLoader is less than the BATCH_SIZE,
        # then it couldn't be fed into the model or there would be an error
        if list(batch_x.size())[0] != BATCH_SIZE:
            break

        # Reset hidden state of encoder for current batch
        h_state = rnn.init_hidden(batch_x.shape[0])
        
        prediction, h_state = rnn(batch_x, h_state)

        loss = loss_func(prediction, batch_y)
        loss.backward()                     # backpropagation, compute gradients
        optimizer.step()                    # apply gradients

        print('Epoch: ', epoch, '| Step: ', step, "| Training Loss(RMSE): ", loss.item()**0.5)

    total_test_loss = 0
    number_of_batch = 0

    rnn.eval()
    
    for i, (batch_full_x, batch_y) in enumerate(test_dataloader):

        batch_x = batch_full_x[:,:,:batch_decoder_x_len]

        # If the last batch from DataLoader is less than the TEST_BATCH_SIZE,
        # then it couldn't be fed into the model or there would be an error
        if list(batch_x.size())[0] != TEST_BATCH_SIZE:
            break

        # Reset hidden state of encoder for current batch
        h_state = rnn.init_hidden(batch_x.shape[0])
        
        prediction, h_state = rnn(batch_x, h_state)

        loss = loss_func(prediction, batch_y)

        total_test_loss += loss.item()
        number_of_batch = i
        
    number_of_batch += 1
    test_rmse = (total_test_loss/number_of_batch)**0.5
    print ("Epoch: ", epoch, "| Test Loss (RMSE): ", test_rmse)
# Out:
# Epoch:  0 | Step:  0 | Training Loss(RMSE):  4.873499908487967
# Epoch:  0 | Step:  1 | Training Loss(RMSE):  4.952523083620997
# Epoch:  0 | Step:  2 | Training Loss(RMSE):  4.856286542403938
# Epoch:  0 | Step:  3 | Training Loss(RMSE):  5.018276951444726
# Epoch:  0 | Step:  4 | Training Loss(RMSE):  4.895133673271775
# Epoch:  0 | Step:  5 | Training Loss(RMSE):  4.771035846704268
# Epoch:  0 | Step:  6 | Training Loss(RMSE):  4.777622217903676
# Epoch:  0 | Test Loss (RMSE):  4.432373847005316
# Epoch:  1 | Step:  0 | Training Loss(RMSE):  4.899262719252841
# Epoch:  1 | Step:  1 | Training Loss(RMSE):  4.78407792378119
# Epoch:  1 | Step:  2 | Training Loss(RMSE):  4.847050483719314
# Epoch:  1 | Step:  3 | Training Loss(RMSE):  4.835598491563009
# Epoch:  1 | Step:  4 | Training Loss(RMSE):  4.816699091044301
# Epoch:  1 | Step:  5 | Training Loss(RMSE):  4.978584393834087
# Epoch:  1 | Step:  6 | Training Loss(RMSE):  4.961643150785565
# Epoch:  1 | Test Loss (RMSE):  4.419434969417875
# Epoch:  2 | Step:  0 | Training Loss(RMSE):  4.845109121316148
# Epoch:  2 | Step:  1 | Training Loss(RMSE):  5.198897560338683
# Epoch:  2 | Step:  2 | Training Loss(RMSE):  4.570826418421385
# Epoch:  2 | Step:  3 | Training Loss(RMSE):  4.779805482553637
# Epoch:  2 | Step:  4 | Training Loss(RMSE):  4.908536924706886
# Epoch:  2 | Step:  5 | Training Loss(RMSE):  4.8455728361918
# Epoch:  2 | Step:  6 | Training Loss(RMSE):  4.7307921093547955
# Epoch:  2 | Test Loss (RMSE):  4.3997379094873565
# Epoch:  3 | Step:  0 | Training Loss(RMSE):  4.926479160076987
# Epoch:  3 | Step:  1 | Training Loss(RMSE):  4.69514350777415
# Epoch:  3 | Step:  2 | Training Loss(RMSE):  4.760638720830792
# Epoch:  3 | Step:  3 | Training Loss(RMSE):  4.805058460336459
# Epoch:  3 | Step:  4 | Training Loss(RMSE):  4.723924843509264
# Epoch:  3 | Step:  5 | Training Loss(RMSE):  4.811424036007683
# Epoch:  3 | Step:  6 | Training Loss(RMSE):  4.771164772925504
# Epoch:  3 | Test Loss (RMSE):  4.3736160269139885
# Epoch:  4 | Step:  0 | Training Loss(RMSE):  4.729884469877533
# Epoch:  4 | Step:  1 | Training Loss(RMSE):  4.792470693165336
# Epoch:  4 | Step:  2 | Training Loss(RMSE):  4.931199701823845
# Epoch:  4 | Step:  3 | Training Loss(RMSE):  5.007931141035637
# Epoch:  4 | Step:  4 | Training Loss(RMSE):  4.425284968106596
# Epoch:  4 | Step:  5 | Training Loss(RMSE):  4.608301690782256
# Epoch:  4 | Step:  6 | Training Loss(RMSE):  4.765090462145158
# Epoch:  4 | Test Loss (RMSE):  4.3374104515308245
# Epoch:  5 | Step:  0 | Training Loss(RMSE):  4.663959649004689
# Epoch:  5 | Step:  1 | Training Loss(RMSE):  4.539426805383643
# Epoch:  5 | Step:  2 | Training Loss(RMSE):  4.659214381846564
# Epoch:  5 | Step:  3 | Training Loss(RMSE):  4.699844585040569
# Epoch:  5 | Step:  4 | Training Loss(RMSE):  4.824314428454041
# Epoch:  5 | Step:  5 | Training Loss(RMSE):  4.770968283975405
# Epoch:  5 | Step:  6 | Training Loss(RMSE):  4.912513379571375
# Epoch:  5 | Test Loss (RMSE):  4.281345227150052
# Epoch:  6 | Step:  0 | Training Loss(RMSE):  4.668534018794717
# Epoch:  6 | Step:  1 | Training Loss(RMSE):  4.72063524594351
# Epoch:  6 | Step:  2 | Training Loss(RMSE):  4.699981551438506
# Epoch:  6 | Step:  3 | Training Loss(RMSE):  4.597171054541251
# Epoch:  6 | Step:  4 | Training Loss(RMSE):  4.6121949960821
# Epoch:  6 | Step:  5 | Training Loss(RMSE):  4.576220640345163
# Epoch:  6 | Step:  6 | Training Loss(RMSE):  4.535161717400881
# Epoch:  6 | Test Loss (RMSE):  4.175986960244556
# Epoch:  7 | Step:  0 | Training Loss(RMSE):  4.601415764585311
# Epoch:  7 | Step:  1 | Training Loss(RMSE):  4.263091624081342
# Epoch:  7 | Step:  2 | Training Loss(RMSE):  4.546980499406975
# Epoch:  7 | Step:  3 | Training Loss(RMSE):  4.5334210686515055
# Epoch:  7 | Step:  4 | Training Loss(RMSE):  4.401979148680175
# Epoch:  7 | Step:  5 | Training Loss(RMSE):  4.553045012662307
# Epoch:  7 | Step:  6 | Training Loss(RMSE):  4.206086090657961
# Epoch:  7 | Test Loss (RMSE):  3.9073403019404975
# Epoch:  8 | Step:  0 | Training Loss(RMSE):  4.0762348106215915
# Epoch:  8 | Step:  1 | Training Loss(RMSE):  4.1522305204899315
# Epoch:  8 | Step:  2 | Training Loss(RMSE):  3.9611025442916827
# Epoch:  8 | Step:  3 | Training Loss(RMSE):  3.8090763666575143
# Epoch:  8 | Step:  4 | Training Loss(RMSE):  3.6619683566598744
# Epoch:  8 | Step:  5 | Training Loss(RMSE):  3.514706504365423
# Epoch:  8 | Step:  6 | Training Loss(RMSE):  3.2466248813371075
# Epoch:  8 | Test Loss (RMSE):  3.09454659118933
# Epoch:  9 | Step:  0 | Training Loss(RMSE):  3.016755835829319
# Epoch:  9 | Step:  1 | Training Loss(RMSE):  2.8485378998907946
# Epoch:  9 | Step:  2 | Training Loss(RMSE):  2.876574209708479
# Epoch:  9 | Step:  3 | Training Loss(RMSE):  2.751801854152846
# Epoch:  9 | Step:  4 | Training Loss(RMSE):  2.741299042408706
# Epoch:  9 | Step:  5 | Training Loss(RMSE):  2.6284191933079306
# Epoch:  9 | Step:  6 | Training Loss(RMSE):  2.521470569953979
# Epoch:  9 | Test Loss (RMSE):  2.715168226871702
# Epoch:  10 | Step:  0 | Training Loss(RMSE):  2.463807482152887
# Epoch:  10 | Step:  1 | Training Loss(RMSE):  2.670522425543285
# Epoch:  10 | Step:  2 | Training Loss(RMSE):  2.4626431805961095
# Epoch:  10 | Step:  3 | Training Loss(RMSE):  2.6703204713437927
# Epoch:  10 | Step:  4 | Training Loss(RMSE):  2.6051152345499853
# Epoch:  10 | Step:  5 | Training Loss(RMSE):  2.568379611671701
# Epoch:  10 | Step:  6 | Training Loss(RMSE):  2.5167081408420047
# Epoch:  10 | Test Loss (RMSE):  2.858298510755466
# Epoch:  11 | Step:  0 | Training Loss(RMSE):  2.4909270635866476
# Epoch:  11 | Step:  1 | Training Loss(RMSE):  2.621103482860795
# Epoch:  11 | Step:  2 | Training Loss(RMSE):  2.621885450158191
# Epoch:  11 | Step:  3 | Training Loss(RMSE):  2.6846821228477915
# Epoch:  11 | Step:  4 | Training Loss(RMSE):  2.4906159710690523
# Epoch:  11 | Step:  5 | Training Loss(RMSE):  2.4877757662402056
# Epoch:  11 | Step:  6 | Training Loss(RMSE):  2.5989403325886413
# Epoch:  11 | Test Loss (RMSE):  2.8520114075029963
# Epoch:  12 | Step:  0 | Training Loss(RMSE):  2.6497235171919002
# Epoch:  12 | Step:  1 | Training Loss(RMSE):  2.5486746204673527
# Epoch:  12 | Step:  2 | Training Loss(RMSE):  2.57278193894566
# Epoch:  12 | Step:  3 | Training Loss(RMSE):  2.5303637047894174
# Epoch:  12 | Step:  4 | Training Loss(RMSE):  2.56568636152927
# Epoch:  12 | Step:  5 | Training Loss(RMSE):  2.425212406412486
# Epoch:  12 | Step:  6 | Training Loss(RMSE):  2.5417151107757343
# Epoch:  12 | Test Loss (RMSE):  2.756973052390218
# Epoch:  13 | Step:  0 | Training Loss(RMSE):  2.42034007008108
# Epoch:  13 | Step:  1 | Training Loss(RMSE):  2.4601369373075914
# Epoch:  13 | Step:  2 | Training Loss(RMSE):  2.4895752995785703
# Epoch:  13 | Step:  3 | Training Loss(RMSE):  2.560623970878828
# Epoch:  13 | Step:  4 | Training Loss(RMSE):  2.352751877827453
# Epoch:  13 | Step:  5 | Training Loss(RMSE):  2.538240364193931
# Epoch:  13 | Step:  6 | Training Loss(RMSE):  2.6503107428547708
# Epoch:  13 | Test Loss (RMSE):  2.6845302141677263
# Epoch:  14 | Step:  0 | Training Loss(RMSE):  2.4743079865301794
# Epoch:  14 | Step:  1 | Training Loss(RMSE):  2.5754793406127994
# Epoch:  14 | Step:  2 | Training Loss(RMSE):  2.501802176359808
# Epoch:  14 | Step:  3 | Training Loss(RMSE):  2.441312791179914
# Epoch:  14 | Step:  4 | Training Loss(RMSE):  2.465555079330544
# Epoch:  14 | Step:  5 | Training Loss(RMSE):  2.440551315152646
# Epoch:  14 | Step:  6 | Training Loss(RMSE):  2.366132041380987
# Epoch:  14 | Test Loss (RMSE):  2.610192039630301
# Epoch:  15 | Step:  0 | Training Loss(RMSE):  2.4210372952689116
# Epoch:  15 | Step:  1 | Training Loss(RMSE):  2.3484735319884784
# Epoch:  15 | Step:  2 | Training Loss(RMSE):  2.3422762497062006
# Epoch:  15 | Step:  3 | Training Loss(RMSE):  2.4383020304167453
# Epoch:  15 | Step:  4 | Training Loss(RMSE):  2.3693487291381476
# Epoch:  15 | Step:  5 | Training Loss(RMSE):  2.4224892114294727
# Epoch:  15 | Step:  6 | Training Loss(RMSE):  2.369309082080306
# Epoch:  15 | Test Loss (RMSE):  2.5588224585429664
# Epoch:  16 | Step:  0 | Training Loss(RMSE):  2.3796466746244125
# Epoch:  16 | Step:  1 | Training Loss(RMSE):  2.3133671140082384
# Epoch:  16 | Step:  2 | Training Loss(RMSE):  2.3319391331458506
# Epoch:  16 | Step:  3 | Training Loss(RMSE):  2.309972670752627
# Epoch:  16 | Step:  4 | Training Loss(RMSE):  2.2758324452019822
# Epoch:  16 | Step:  5 | Training Loss(RMSE):  2.333595760665145
# Epoch:  16 | Step:  6 | Training Loss(RMSE):  2.21174310356161
# Epoch:  16 | Test Loss (RMSE):  2.582994890090549
# Epoch:  17 | Step:  0 | Training Loss(RMSE):  2.2801985734498635
# Epoch:  17 | Step:  1 | Training Loss(RMSE):  2.3489502246206415
# Epoch:  17 | Step:  2 | Training Loss(RMSE):  2.374359044370087
# Epoch:  17 | Step:  3 | Training Loss(RMSE):  2.252362388615757
# Epoch:  17 | Step:  4 | Training Loss(RMSE):  2.167917171930091
# Epoch:  17 | Step:  5 | Training Loss(RMSE):  2.2344995210535674
# Epoch:  17 | Step:  6 | Training Loss(RMSE):  2.293008677250331
# Epoch:  17 | Test Loss (RMSE):  2.5653859611417955
# Epoch:  18 | Step:  0 | Training Loss(RMSE):  2.1698568284580113
# Epoch:  18 | Step:  1 | Training Loss(RMSE):  2.2695640259573913
# Epoch:  18 | Step:  2 | Training Loss(RMSE):  2.2507444845452125
# Epoch:  18 | Step:  3 | Training Loss(RMSE):  2.3278683514551552
# Epoch:  18 | Step:  4 | Training Loss(RMSE):  2.3198293060780095
# Epoch:  18 | Step:  5 | Training Loss(RMSE):  2.146522806255708
# Epoch:  18 | Step:  6 | Training Loss(RMSE):  2.219284960231717
# Epoch:  18 | Test Loss (RMSE):  2.523644784261713
# Epoch:  19 | Step:  0 | Training Loss(RMSE):  2.2820168865291186
# Epoch:  19 | Step:  1 | Training Loss(RMSE):  2.214045197305527
# Epoch:  19 | Step:  2 | Training Loss(RMSE):  2.2204844183406256
# Epoch:  19 | Step:  3 | Training Loss(RMSE):  2.241031574726447
# Epoch:  19 | Step:  4 | Training Loss(RMSE):  2.1843306333650436
# Epoch:  19 | Step:  5 | Training Loss(RMSE):  2.2433717371623083
# Epoch:  19 | Step:  6 | Training Loss(RMSE):  2.1518458848103172
# Epoch:  19 | Test Loss (RMSE):  2.5199513639570474
# Epoch:  20 | Step:  0 | Training Loss(RMSE):  2.254940542718652
# Epoch:  20 | Step:  1 | Training Loss(RMSE):  2.1813078296067387
# Epoch:  20 | Step:  2 | Training Loss(RMSE):  2.1958242885492596
# Epoch:  20 | Step:  3 | Training Loss(RMSE):  2.147193798399609
# Epoch:  20 | Step:  4 | Training Loss(RMSE):  2.1940583145542862
# Epoch:  20 | Step:  5 | Training Loss(RMSE):  2.203898733640752
# Epoch:  20 | Step:  6 | Training Loss(RMSE):  2.14345580548552
# Epoch:  20 | Test Loss (RMSE):  2.5141830576648014
# Epoch:  21 | Step:  0 | Training Loss(RMSE):  2.2056767180841543
# Epoch:  21 | Step:  1 | Training Loss(RMSE):  2.2246121615023156
# Epoch:  21 | Step:  2 | Training Loss(RMSE):  2.0905315657693446
# Epoch:  21 | Step:  3 | Training Loss(RMSE):  2.2365973031572937
# Epoch:  21 | Step:  4 | Training Loss(RMSE):  2.110477300778966
# Epoch:  21 | Step:  5 | Training Loss(RMSE):  2.213386392570204
# Epoch:  21 | Step:  6 | Training Loss(RMSE):  2.1714407946486376
# Epoch:  21 | Test Loss (RMSE):  2.478331502654223
# Epoch:  22 | Step:  0 | Training Loss(RMSE):  2.1045413549215883
# Epoch:  22 | Step:  1 | Training Loss(RMSE):  2.152341202251498
# Epoch:  22 | Step:  2 | Training Loss(RMSE):  2.146260882501667
# Epoch:  22 | Step:  3 | Training Loss(RMSE):  2.1366503493607896
# Epoch:  22 | Step:  4 | Training Loss(RMSE):  2.1706337434925937
# Epoch:  22 | Step:  5 | Training Loss(RMSE):  2.151690430671229
# Epoch:  22 | Step:  6 | Training Loss(RMSE):  2.183527363704626
# Epoch:  22 | Test Loss (RMSE):  2.4544306882364664
# Epoch:  23 | Step:  0 | Training Loss(RMSE):  2.228964169535591
# Epoch:  23 | Step:  1 | Training Loss(RMSE):  2.1218907666077063
# Epoch:  23 | Step:  2 | Training Loss(RMSE):  2.1444019494049087
# Epoch:  23 | Step:  3 | Training Loss(RMSE):  2.175377854597269
# Epoch:  23 | Step:  4 | Training Loss(RMSE):  2.1560783870792983
# Epoch:  23 | Step:  5 | Training Loss(RMSE):  2.1432766049690635
# Epoch:  23 | Step:  6 | Training Loss(RMSE):  2.1456667147147446
# Epoch:  23 | Test Loss (RMSE):  2.4480542299833665
# Epoch:  24 | Step:  0 | Training Loss(RMSE):  2.054332629986309
# Epoch:  24 | Step:  1 | Training Loss(RMSE):  2.084604701892682
# Epoch:  24 | Step:  2 | Training Loss(RMSE):  2.180023276878468
# Epoch:  24 | Step:  3 | Training Loss(RMSE):  2.2096533399014975
# Epoch:  24 | Step:  4 | Training Loss(RMSE):  2.1365079618877427
# Epoch:  24 | Step:  5 | Training Loss(RMSE):  2.1852698811079576
# Epoch:  24 | Step:  6 | Training Loss(RMSE):  2.1019080349506583
# Epoch:  24 | Test Loss (RMSE):  2.441273873364297
# Epoch:  25 | Step:  0 | Training Loss(RMSE):  2.1600487459828246
# Epoch:  25 | Step:  1 | Training Loss(RMSE):  2.181641608556459
# Epoch:  25 | Step:  2 | Training Loss(RMSE):  2.09236440786676
# Epoch:  25 | Step:  3 | Training Loss(RMSE):  2.0922954688157467
# Epoch:  25 | Step:  4 | Training Loss(RMSE):  2.0496149724989676
# Epoch:  25 | Step:  5 | Training Loss(RMSE):  2.148417413791048
# Epoch:  25 | Step:  6 | Training Loss(RMSE):  2.1052260674798164
# Epoch:  25 | Test Loss (RMSE):  2.429311545377244
# Epoch:  26 | Step:  0 | Training Loss(RMSE):  2.020188245027953
# Epoch:  26 | Step:  1 | Training Loss(RMSE):  2.141186494347622
# Epoch:  26 | Step:  2 | Training Loss(RMSE):  2.100523057011541
# Epoch:  26 | Step:  3 | Training Loss(RMSE):  2.0919805992787763
# Epoch:  26 | Step:  4 | Training Loss(RMSE):  2.14155246662688
# Epoch:  26 | Step:  5 | Training Loss(RMSE):  2.0795818757735063
# Epoch:  26 | Step:  6 | Training Loss(RMSE):  2.0837982294809025
# Epoch:  26 | Test Loss (RMSE):  2.431506196867796
# Epoch:  27 | Step:  0 | Training Loss(RMSE):  2.018996265613868
# Epoch:  27 | Step:  1 | Training Loss(RMSE):  2.151201391563093
# Epoch:  27 | Step:  2 | Training Loss(RMSE):  2.1116407870438287
# Epoch:  27 | Step:  3 | Training Loss(RMSE):  2.0391959077302406
# Epoch:  27 | Step:  4 | Training Loss(RMSE):  2.0534284672228593
# Epoch:  27 | Step:  5 | Training Loss(RMSE):  2.1125757869691864
# Epoch:  27 | Step:  6 | Training Loss(RMSE):  2.1164576549912577
# Epoch:  27 | Test Loss (RMSE):  2.4093353010932024
# Epoch:  28 | Step:  0 | Training Loss(RMSE):  2.020041779378781
# Epoch:  28 | Step:  1 | Training Loss(RMSE):  2.088438213827173
# Epoch:  28 | Step:  2 | Training Loss(RMSE):  2.1042590231188156
# Epoch:  28 | Step:  3 | Training Loss(RMSE):  2.1646784928240317
# Epoch:  28 | Step:  4 | Training Loss(RMSE):  2.0935548150480416
# Epoch:  28 | Step:  5 | Training Loss(RMSE):  2.105750806384185
# Epoch:  28 | Step:  6 | Training Loss(RMSE):  2.0004712980004324
# Epoch:  28 | Test Loss (RMSE):  2.4011520779614135
# Epoch:  29 | Step:  0 | Training Loss(RMSE):  2.122933224160186
# Epoch:  29 | Step:  1 | Training Loss(RMSE):  2.0321399793094503
# Epoch:  29 | Step:  2 | Training Loss(RMSE):  2.0230657169682154
# Epoch:  29 | Step:  3 | Training Loss(RMSE):  2.1339363239373244
# Epoch:  29 | Step:  4 | Training Loss(RMSE):  2.083030704134645
# Epoch:  29 | Step:  5 | Training Loss(RMSE):  1.960350951965912
# Epoch:  29 | Step:  6 | Training Loss(RMSE):  2.123251700676071
# Epoch:  29 | Test Loss (RMSE):  2.4253080585302915
# Epoch:  30 | Step:  0 | Training Loss(RMSE):  2.1236965445290505
# Epoch:  30 | Step:  1 | Training Loss(RMSE):  2.0360034197120953
# Epoch:  30 | Step:  2 | Training Loss(RMSE):  2.0452533150918706
# Epoch:  30 | Step:  3 | Training Loss(RMSE):  2.0577244814366926
# Epoch:  30 | Step:  4 | Training Loss(RMSE):  1.9632941443326877
# Epoch:  30 | Step:  5 | Training Loss(RMSE):  2.067050076369461
# Epoch:  30 | Step:  6 | Training Loss(RMSE):  2.0546741557685144
# Epoch:  30 | Test Loss (RMSE):  2.4152367461203843
# Epoch:  31 | Step:  0 | Training Loss(RMSE):  2.04573003763237
# Epoch:  31 | Step:  1 | Training Loss(RMSE):  2.0155556836888167
# Epoch:  31 | Step:  2 | Training Loss(RMSE):  2.027919915267676
# Epoch:  31 | Step:  3 | Training Loss(RMSE):  2.006387761695321
# Epoch:  31 | Step:  4 | Training Loss(RMSE):  1.995038673771757
# Epoch:  31 | Step:  5 | Training Loss(RMSE):  2.0777766573943155
# Epoch:  31 | Step:  6 | Training Loss(RMSE):  2.013094237364039
# Epoch:  31 | Test Loss (RMSE):  2.4250726570964125
# Epoch:  32 | Step:  0 | Training Loss(RMSE):  2.0219125782512397
# Epoch:  32 | Step:  1 | Training Loss(RMSE):  1.981615385424564
# Epoch:  32 | Step:  2 | Training Loss(RMSE):  1.9920343078355227
# Epoch:  32 | Step:  3 | Training Loss(RMSE):  2.017692747303705
# Epoch:  32 | Step:  4 | Training Loss(RMSE):  2.066360675042373
# Epoch:  32 | Step:  5 | Training Loss(RMSE):  2.045372331296386
# Epoch:  32 | Step:  6 | Training Loss(RMSE):  2.086114540159362
# Epoch:  32 | Test Loss (RMSE):  2.441313523629718
# Epoch:  33 | Step:  0 | Training Loss(RMSE):  1.9899110241268705
# Epoch:  33 | Step:  1 | Training Loss(RMSE):  2.0218055064597404
# Epoch:  33 | Step:  2 | Training Loss(RMSE):  2.010592662111297
# Epoch:  33 | Step:  3 | Training Loss(RMSE):  1.9932407362533788
# Epoch:  33 | Step:  4 | Training Loss(RMSE):  2.0100047689352825
# Epoch:  33 | Step:  5 | Training Loss(RMSE):  2.0657495273560462
# Epoch:  33 | Step:  6 | Training Loss(RMSE):  2.050133942671026
# Epoch:  33 | Test Loss (RMSE):  2.4178902115646306
# Epoch:  34 | Step:  0 | Training Loss(RMSE):  2.0176398091520444
# Epoch:  34 | Step:  1 | Training Loss(RMSE):  1.9972800594698308
# Epoch:  34 | Step:  2 | Training Loss(RMSE):  2.055337201225674
# Epoch:  34 | Step:  3 | Training Loss(RMSE):  2.065151706323144
# Epoch:  34 | Step:  4 | Training Loss(RMSE):  2.0159508493502143
# Epoch:  34 | Step:  5 | Training Loss(RMSE):  1.961527762160889
# Epoch:  34 | Step:  6 | Training Loss(RMSE):  2.0500626531191353
# Epoch:  34 | Test Loss (RMSE):  2.402238945884651
# Epoch:  35 | Step:  0 | Training Loss(RMSE):  1.9492432128349717
# Epoch:  35 | Step:  1 | Training Loss(RMSE):  1.944124648120696
# Epoch:  35 | Step:  2 | Training Loss(RMSE):  2.0581128248126253
# Epoch:  35 | Step:  3 | Training Loss(RMSE):  2.070236722890924
# Epoch:  35 | Step:  4 | Training Loss(RMSE):  1.9442499161855515
# Epoch:  35 | Step:  5 | Training Loss(RMSE):  1.993091512777337
# Epoch:  35 | Step:  6 | Training Loss(RMSE):  2.0568138114848282
# Epoch:  35 | Test Loss (RMSE):  2.4037775490581144
# Wall time: 16min 6s
