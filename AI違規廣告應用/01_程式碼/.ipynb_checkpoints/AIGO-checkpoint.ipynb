# %%
from PIL import Image
import matplotlib.pyplot as plt
from wordcloud import WordCloud, ImageColorGenerator
import jieba
import numpy as np
from collections import Counter

# %%
#設定字典
jieba.set_dictionary('dict.txt.big')
#jieba.load_userdict(r'userdict_mayday.txt')
 
#設定停用詞
with open(r'stop_words.txt', 'r', encoding='utf8') as f:  
    stops = f.read().split('\n') 
 
#
#開始段詞與排序，沒錯就這麼簡單就做完了
#
text_from_file_with_apath = open('test.txt', "r", encoding="utf-8").read()
terms = [t for t in jieba.cut(text_from_file_with_apath, cut_all=True) if t not in stops]
sorted(Counter(terms).items(), key=lambda x:x[1], reverse=True)
# Out:
# Building prefix dict from C:\Users\Kevin\Code\AIGO\dict.txt.big ...
# Loading model from cache C:\Users\Kevin\AppData\Local\Temp\jieba.u28293b670163f4b565fccef7fee3075a.cache
# Loading model cost 1.998 seconds.
# Prefix dict has been built succesfully.
# [('\n', 110),
#  ('脂肪', 90),
#  ('關節', 75),
#  ('改善', 50),
#  ('減少', 40),
#  ('軟骨', 39),
#  ('降低', 38),
#  ('代謝', 36),
#  ('免疫', 36),
#  ('脂', 34),
#  ('髮', 34),
#  ('預防', 33),
#  ('細胞', 33),
#  ('促進', 33),
#  ('吃', 32),
#  ('氧化', 31),
#  ('抑制', 30),
#  ('蛋白', 27),
#  ('效果', 26),
#  ('營養', 26),
#  ('作用', 26),
#  ('掉', 26),
#  ('抗氧化', 25),
#  ('固醇', 24),
#  ('幫助', 24),
#  ('燃燒', 24),
#  ('有效', 23),
#  ('膽固醇', 23),
#  ('血壓', 22),
#  ('增加', 22),
#  ('退化', 22),
#  ('免疫力', 21),
#  ('好', 21),
#  ('體內', 21),
#  ('功能', 21),
#  ('提升', 21),
#  ('膝蓋', 21),
#  ('身體', 20),
#  ('飲', 20),
#  ('型', 20),
#  ('皮膚', 20),
#  ('分解', 19),
#  ('血管', 19),
#  ('提高', 19),
#  ('膠原', 19),
#  ('疼痛', 19),
#  ('吸收', 18),
#  ('容易', 18),
#  ('修復', 18),
#  ('酵素', 17),
#  ('減', 17),
#  ('腸道', 17),
#  ('功效', 17),
#  ('眼睛', 17),
#  ('美', 16),
#  ('產生', 16),
#  ('健康', 16),
#  ('人體', 16),
#  ('膠原蛋白', 16),
#  ('高', 15),
#  ('系統', 15),
#  ('體重', 15),
#  ('增強', 15),
#  ('錠', 15),
#  ('胖', 14),
#  ('後', 14),
#  ('纖', 14),
#  ('便秘', 14),
#  ('具有', 14),
#  ('天然', 14),
#  ('發炎', 14),
#  ('癌症', 14),
#  ('益生菌', 14),
#  ('老化', 14),
#  ('量', 14),
#  ('頭髮', 14),
#  ('素', 13),
#  ('減肥', 13),
#  ('泌尿', 13),
#  ('抗', 13),
#  ('油', 13),
#  ('保護', 13),
#  ('疾病', 13),
#  ('糖尿', 13),
#  ('疲勞', 13),
#  ('正常', 13),
#  ('肌膚', 13),
#  ('增', 13),
#  ('腹部', 13),
#  ('調節', 12),
#  ('越', 12),
#  ('減重', 12),
#  ('高血壓', 12),
#  ('糖尿病', 12),
#  ('硒', 12),
#  ('再生', 12),
#  ('補充', 12),
#  ('保養', 12),
#  ('膝關', 12),
#  ('膝關節', 12),
#  ('膠囊', 11),
#  ('瘦', 11),
#  ('瘦身', 11),
#  ('認證', 11),
#  ('人', 11),
#  ('體', 11),
#  ('天', 11),
#  ('菌', 11),
#  ('能量', 11),
#  ('發生', 11),
#  ('力', 11),
#  ('茶', 11),
#  ('使用', 11),
#  ('肌肉', 11),
#  ('肝', 11),
#  ('血糖', 11),
#  ('100', 11),
#  ('自由', 11),
#  ('自由基', 11),
#  ('生長', 11),
#  ('青春', 11),
#  ('細菌', 11),
#  ('過敏', 11),
#  ('問題', 11),
#  ('年', 10),
#  ('咖啡', 10),
#  ('形成', 10),
#  ('中', 10),
#  ('抵抗', 10),
#  ('恢復', 10),
#  ('維持', 10),
#  ('黃素', 10),
#  ('佐', 10),
#  ('血液', 10),
#  ('月', 10),
#  ('醫生', 10),
#  ('內臟', 10),
#  ('維生', 10),
#  ('維生素', 10),
#  ('精', 10),
#  ('體質', 10),
#  ('尿路', 10),
#  ('隆乳', 10),
#  ('組', 9),
#  ('物質', 9),
#  ('防止', 9),
#  ('排毒', 9),
#  ('公斤', 9),
#  ('症狀', 9),
#  ('說', 9),
#  ('每天', 9),
#  ('芝麻', 9),
#  ('心臟', 9),
#  ('美國', 9),
#  ('活化', 9),
#  ('黑', 9),
#  ('女性', 9),
#  ('肥胖', 9),
#  ('衰老', 9),
#  ('葉黃素', 9),
#  ('新陳代謝', 9),
#  ('萃取', 9),
#  ('葡萄', 9),
#  ('磨損', 9),
#  ('酸性', 9),
#  ('速', 9),
#  ('痛', 9),
#  ('已經', 9),
#  ('果', 8),
#  ('大量', 8),
#  ('感染', 8),
#  ('10', 8),
#  ('物', 8),
#  ('大腦', 8),
#  ('心血', 8),
#  ('心血管', 8),
#  ('質', 8),
#  ('關節炎', 8),
#  ('壓力', 8),
#  ('組織', 8),
#  ('有助', 8),
#  ('症候', 8),
#  ('症候群', 8),
#  ('感冒', 8),
#  ('嚴重', 8),
#  ('防癌', 8),
#  ('食品', 8),
#  ('控制', 8),
#  ('循環', 8),
#  ('養生', 8),
#  ('長期', 8),
#  ('緩解', 8),
#  ('時', 8),
#  ('增生', 8),
#  ('神經', 8),
#  ('圖', 8),
#  ('少', 8),
#  ('下降', 8),
#  ('機能', 8),
#  ('燃', 7),
#  ('倍', 7),
#  ('腰圍', 7),
#  ('排出', 7),
#  ('心肌', 7),
#  ('血脂', 7),
#  ('寶', 7),
#  ('輕鬆', 7),
#  ('覺得', 7),
#  ('腸胃', 7),
#  ('大腸', 7),
#  ('失眠', 7),
#  ('元素', 7),
#  ('多種', 7),
#  ('配方', 7),
#  ('狀況', 7),
#  ('牡蠣', 7),
#  ('肝臟', 7),
#  ('研究', 7),
#  ('持續', 7),
#  ('不適', 7),
#  ('化性', 7),
#  ('能力', 7),
#  ('藍光', 7),
#  ('更年期', 7),
#  ('年期', 7),
#  ('抗老', 7),
#  ('傷害', 7),
#  ('產品', 7),
#  ('卡', 7),
#  ('藥物', 7),
#  ('舒緩', 7),
#  ('比較', 7),
#  ('牛', 7),
#  ('消化', 7),
#  ('精華', 7),
#  ('營養素', 7),
#  ('蜂蜜', 7),
#  ('C', 7),
#  ('莢膜', 7),
#  ('專利', 6),
#  ('生', 6),
#  ('毒', 6),
#  ('合成', 6),
#  ('核桃', 6),
#  ('補', 6),
#  ('提早', 6),
#  ('記憶', 6),
#  ('抵抗力', 6),
#  ('抗力', 6),
#  ('缺乏', 6),
#  ('防護', 6),
#  ('糖', 6),
#  ('快速', 6),
#  ('導致', 6),
#  ('腸癌', 6),
#  ('抗菌', 6),
#  ('心臟病', 6),
#  ('損傷', 6),
#  ('富', 6),
#  ('麵', 6),
#  ('有助於', 6),
#  ('助於', 6),
#  ('益', 6),
#  ('飲食', 6),
#  ('造成', 6),
#  ('奶', 6),
#  ('使', 6),
#  ('醫學', 6),
#  ('族', 6),
#  ('分泌', 6),
#  ('超級', 6),
#  ('對抗', 6),
#  ('肌', 6),
#  ('管理', 6),
#  ('高達', 6),
#  ('減緩', 6),
#  ('群', 6),
#  ('鈣', 6),
#  ('視力', 6),
#  ('情緒', 6),
#  ('睡眠', 6),
#  ('水腫', 6),
#  ('非', 6),
#  ('變性', 6),
#  ('環境', 6),
#  ('之後', 6),
#  ('葡萄糖', 6),
#  ('消除', 6),
#  ('青梅', 6),
#  ('護眼', 6),
#  ('眼', 6),
#  ('老公', 6),
#  ('喝', 6),
#  ('內膜', 6),
#  ('術後', 6),
#  ('啟', 5),
#  ('動', 5),
#  ('變', 5),
#  ('血', 5),
#  ('15', 5),
#  ('協助', 5),
#  ('有益', 5),
#  ('外', 5),
#  ('胃', 5),
#  ('莓', 5),
#  ('來自', 5),
#  ('免疫系統', 5),
#  ('達到', 5),
#  ('清除', 5),
#  ('傷口', 5),
#  ('癒合', 5),
#  ('小', 5),
#  ('堆積', 5),
#  ('油脂', 5),
#  ('腦', 5),
#  ('黃金', 5),
#  ('一定', 5),
#  ('一個', 5),
#  ('降血壓', 5),
#  ('老年', 5),
#  ('燥', 5),
#  ('腸', 5),
#  ('需要', 5),
#  ('差', 5),
#  ('保', 5),
#  ('日本', 5),
#  ('丸', 5),
#  ('患者', 5),
#  ('抗癌', 5),
#  ('龜', 5),
#  ('紫外', 5),
#  ('紫外線', 5),
#  ('外線', 5),
#  ('人生', 5),
#  ('緊', 5),
#  ('延緩', 5),
#  ('彈性', 5),
#  ('金盞', 5),
#  ('金盞花', 5),
#  ('水', 5),
#  ('服用', 5),
#  ('長庚', 5),
#  ('98', 5),
#  ('骨', 5),
#  ('骨質', 5),
#  ('密度', 5),
#  ('多重', 5),
#  ('體力', 5),
#  ('現在', 5),
#  ('消', 5),
#  ('症', 5),
#  ('薑黃', 5),
#  ('50', 5),
#  ('促使', 5),
#  ('緊張', 5),
#  ('品質', 5),
#  ('發現', 5),
#  ('完', 5),
#  ('歲', 5),
#  ('芝', 5),
#  ('下來', 5),
#  ('益處', 5),
#  ('出現', 5),
#  ('澳洲', 5),
#  ('治療', 5),
#  ('因子', 5),
#  ('醇', 5),
#  ('尿', 5),
#  ('老婆', 5),
#  ('柔軟', 5),
#  ('攣縮', 5),
#  ('梅', 5),
#  ('核酸', 5),
#  ('緣', 5),
#  ('授', 5),
#  ('連續', 4),
#  ('食用', 4),
#  ('世界', 4),
#  ('專業', 4),
#  ('泡', 4),
#  ('平均', 4),
#  ('35', 4),
#  ('花青素', 4),
#  ('顆', 4),
#  ('中性', 4),
#  ('桿菌', 4),
#  ('一種', 4),
#  ('氧化物', 4),
#  ('病毒', 4),
#  ('袪', 4),
#  ('腰', 4),
#  ('易', 4),
#  ('24', 4),
#  ('小時', 4),
#  ('度', 4),
#  ('床', 4),
#  ('飲用', 4),
#  ('明顯', 4),
#  ('裡', 4),
#  ('定要', 4),
#  ('失調', 4),
#  ('痠痛', 4),
#  ('防護力', 4),
#  ('平衡', 4),
#  ('酸', 4),
#  ('負擔', 4),
#  ('病變', 4),
#  ('機率', 4),
#  ('風險', 4),
#  ('前', 4),
#  ('85', 4),
#  ('蝦', 4),
#  ('紅素', 4),
#  ('腫瘤', 4),
#  ('呼吸', 4),
#  ('中風', 4),
#  ('憂鬱', 4),
#  ('膳食', 4),
#  ('死亡', 4),
#  ('死亡率', 4),
#  ('關係', 4),
#  ('白菜', 4),
#  ('烏龍', 4),
#  ('利膽', 4),
#  ('肝功', 4),
#  ('肝功能', 4),
#  ('醣', 4),
#  ('升高', 4),
#  ('X', 4),
#  ('生理', 4),
#  ('乳酸', 4),
#  ('曲線', 4),
#  ('大腸癌', 4),
#  ('流失', 4),
#  ('美體', 4),
#  ('穿', 4),
#  ('激素', 4),
#  ('毒素', 4),
#  ('輕度', 4),
#  ('寶寶', 4),
#  ('性', 4),
#  ('肚子', 4),
#  ('低', 4),
#  ('20', 4),
#  ('解毒', 4),
#  ('朋友', 4),
#  ('紅', 4),
#  ('肉', 4),
#  ('模糊', 4),
#  ('子宮', 4),
#  ('經痛', 4),
#  ('活血', 4),
#  ('荷爾', 4),
#  ('荷爾蒙', 4),
#  ('安全', 4),
#  ('花葉', 4),
#  ('刺激', 4),
#  ('附', 4),
#  ('脂肪酸', 4),
#  ('珍', 4),
#  ('活性', 4),
#  ('國藥', 4),
#  ('管理局', 4),
#  ('頒發', 4),
#  ('研發', 4),
#  ('液', 4),
#  ('96', 4),
#  ('骨刺', 4),
#  ('布', 4),
#  ('緩釋', 4),
#  ('B', 4),
#  ('分鐘', 4),
#  ('焦慮', 4),
#  ('350', 4),
#  ('困擾', 4),
#  ('顧', 4),
#  ('新', 4),
#  ('不好', 4),
#  ('一下', 4),
#  ('活動', 4),
#  ('鬆弛', 4),
#  ('反應', 4),
#  ('木', 4),
#  ('醋栗', 4),
#  ('腳', 4),
#  ('皺紋', 4),
#  ('樟', 4),
#  ('癌', 4),
#  ('不良', 4),
#  ('鉀', 4),
#  ('雙', 4),
#  ('嗜', 4),
#  ('重要', 4),
#  ('醫師', 4),
#  ('不足', 4),
#  ('血液循環', 4),
#  ('率', 4),
#  ('成分', 4),
#  ('纖維', 4),
#  ('避免', 4),
#  ('稱', 4),
#  ('活力', 4),
#  ('胺', 4),
#  ('修護', 4),
#  ('骨骼', 4),
#  ('逐漸', 4),
#  ('減輕', 4),
#  ('II', 4),
#  ('滑', 4),
#  ('骨頭', 4),
#  ('緩和', 4),
#  ('感', 4),
#  ('太多', 4),
#  ('圖片', 4),
#  ('無', 4),
#  ('腎', 4),
#  ('煩惱', 4),
#  ('脾', 4),
#  ('鮑魚', 4),
#  ('副作用', 4),
#  ('芭樂', 4),
#  ('進入', 4),
#  ('面積', 4),
#  ('低脂肪', 4),
#  ('惡病質', 4),
#  ('病患', 4),
#  ('約', 4),
#  ('狀態', 4),
#  ('不用', 4),
#  ('排解', 4),
#  ('龐德', 4),
#  ('利', 3),
#  ('酒精', 3),
#  ('實驗', 3),
#  ('證實', 3),
#  ('防彈', 3),
#  ('做', 3),
#  ('人士', 3),
#  ('橙', 3),
#  ('斑', 3),
#  ('名', 3),
#  ('攝取', 3),
#  ('指數', 3),
#  ('黑色', 3),
#  ('黑色素', 3),
#  ('色素', 3),
#  ('成份', 3),
#  ('有害', 3),
#  ('可防', 3),
#  ('體外', 3),
#  ('泌尿道', 3),
#  ('尿道', 3),
#  ('蔓', 3),
#  ('喚醒', 3),
#  ('基', 3),
#  ('慢性', 3),
#  ('加速', 3),
#  ('超', 3),
#  ('降血脂', 3),
#  ('尿酸', 3),
#  ('回', 3),
#  ('陳', 3),
#  ('關鍵', 3),
#  ('醫', 3),
#  ('基因', 3),
#  ('下', 3),
#  ('立即', 3),
#  ('360', 3),
#  ('阻斷', 3),
#  ('液態', 3),
#  ('堅果', 3),
#  ('壞', 3),
#  ('最近', 3),
#  ('桃', 3),
#  ('記憶力', 3),
#  ('殺菌', 3),
#  ('強化', 3),
#  ('包', 3),
#  ('甩', 3),
#  ('喔', 3),
#  ('蜂王', 3),
#  ('綜合', 3),
#  ('氧化作用', 3),
#  ('化作', 3),
#  ('防老', 3),
#  ('風', 3),
#  ('濕', 3),
#  ('頭暈', 3),
#  ('耳鳴', 3),
#  ('炎', 3),
#  ('腦中風', 3),
#  ('萎縮', 3),
#  ('報告', 3),
#  ('腎臟', 3),
#  ('白內障', 3),
#  ('內障', 3),
#  ('40', 3),
#  ('維他命', 3),
#  ('指出', 3),
#  ('胃癌', 3),
#  ('血球', 3),
#  ('酵母', 3),
#  ('減肥茶', 3),
#  ('發病', 3),
#  ('程度', 3),
#  ('發育', 3),
#  ('調理', 3),
#  ('病', 3),
#  ('結石', 3),
#  ('鐵', 3),
#  ('身材', 3),
#  ('套', 3),
#  ('胸部', 3),
#  ('生育', 3),
#  ('次數', 3),
#  ('硬度', 3),
#  ('母乳', 3),
#  ('生病', 3),
#  ('抗衰老', 3),
#  ('逆轉', 3),
#  ('平常', 3),
#  ('便祕', 3),
#  ('馬', 3),
#  ('頂級', 3),
#  ('含量', 3),
#  ('植物', 3),
#  ('性慾', 3),
#  ('寒', 3),
#  ('全身', 3),
#  ('碳水', 3),
#  ('碳水化合物', 3),
#  ('水化', 3),
#  ('化合', 3),
#  ('化合物', 3),
#  ('糖分', 3),
#  ('食慾', 3),
#  ('複方', 3),
#  ('越來', 3),
#  ('越來越', 3),
#  ('易怒', 3),
#  ('睡', 3),
#  ('抗疲勞', 3),
#  ('鎂', 3),
#  ('脹氣', 3),
#  ('鹿', 3),
#  ('硬骨', 3),
#  ('95', 3),
#  ('醫療', 3),
#  ('中醫', 3),
#  ('骨科', 3),
#  ('吸收率', 3),
#  ('收率', 3),
#  ('夜', 3),
#  ('以下', 3),
#  ('安定', 3),
#  ('320', 3),
#  ('半年', 3),
#  ('30', 3),
#  ('技術', 3),
#  ('醫院', 3),
#  ('擺脫', 3),
#  ('底', 3),
#  ('暗', 3),
#  ('沉', 3),
#  ('精益', 3),
#  ('腦部', 3),
#  ('強', 3),
#  ('平滑', 3),
#  ('鱉', 3),
#  ('白金', 3),
#  ('葡萄籽', 3),
#  ('亮', 3),
#  ('無法', 3),
#  ('卻', 3),
#  ('賀爾蒙', 3),
#  ('萬', 3),
#  ('來源', 3),
#  ('效', 3),
#  ('品', 3),
#  ('囤積', 3),
#  ('受', 3),
#  ('化身', 3),
#  ('小腹', 3),
#  ('高血脂', 3),
#  ('檢查', 3),
#  ('變好', 3),
#  ('穩定', 3),
#  ('擁有', 3),
#  ('更是', 3),
#  ('主要', 3),
#  ('許多', 3),
#  ('疏鬆', 3),
#  ('結構', 3),
#  ('水分', 3),
#  ('軟骨素', 3),
#  ('害', 3),
#  ('Casinoest', 3),
#  ('239', 3),
#  ('MayuraStation', 3),
#  ('牧場', 3),
#  ('旺', 3),
#  ('養護', 3),
#  ('太', 3),
#  ('有機', 3),
#  ('0800552020', 3),
#  ('養', 3),
#  ('含有', 3),
#  ('蛋白質', 3),
#  ('白質', 3),
#  ('礦物', 3),
#  ('礦物質', 3),
#  ('部位', 3),
#  ('加快', 3),
#  ('保持', 3),
#  ('提供', 3),
#  ('生成', 3),
#  ('運動', 3),
#  ('白藜蘆醇', 3),
#  ('藜蘆', 3),
#  ('23', 3),
#  ('透過', 3),
#  ('現代', 3),
#  ('看到', 3),
#  ('番茄', 3),
#  ('頻', 3),
#  ('公司', 3),
#  ('最', 3),
#  ('明天', 3),
#  ('真的', 3),
#  ('鈣質', 3),
#  ('發福', 3),
#  ('食', 3),
#  ('族群', 3),
#  ('內脂', 3),
#  ('阻擋', 3),
#  ('年輕', 3),
#  ('痛感', 3),
#  ('緻', 3),
#  ('稀疏', 3),
#  ('受損', 3),
#  ('DOWN', 3),
#  ('余', 3),
#  ('甘子', 3),
#  ('好處', 3),
#  ('硬', 3),
#  ('照顧', 3),
#  ('遠離', 3),
#  ('隆胸', 3),
#  ('過度', 3),
#  ('妍', 3),
#  ('屬', 3),
#  ('鹼性', 3),
#  ('規律', 3),
#  ('重金', 3),
#  ('重金屬', 3),
#  ('金屬', 3),
#  ('白蘭', 3),
#  ('氏', 3),
#  ('懷孕', 3),
#  ('壽命', 3),
#  ('一罐', 3),
#  ('DLPC', 2),
#  ('軟膠', 2),
#  ('軟膠囊', 2),
#  ('驗證', 2),
#  ('可有', 2),
#  ('青', 2),
#  ('汁', 2),
#  ('方法', 2),
#  ('唯一', 2),
#  ('取得', 2),
#  ('子彈', 2),
#  ('狠', 2),
#  ('準', 2),
#  ('最大', 2),
#  ('測試', 2),
#  ('淡', 2),
#  ('18', 2),
#  ('受試者', 2),
#  ('照射', 2),
#  ('最高', 2),
#  ('養成', 2),
#  ('有益菌', 2),
#  ('繁殖', 2),
#  ('膽汁', 2),
#  ('膽汁酸', 2),
#  ('幽門', 2),
#  ('螺旋', 2),
#  ('螺旋桿菌', 2),
#  ('引起', 2),
#  ('尿道感染', 2),
#  ('過氧', 2),
#  ('過氧化', 2),
#  ('慢性病', 2),
#  ('性病', 2),
#  ('缺氧', 2),
#  ('厲害', 2),
#  ('排除', 2),
#  ('渴望', 2),
#  ('塑型', 2),
#  ('川', 2),
#  ('皮', 2),
#  ('挑戰', 2),
#  ('213', 2),
#  ('週', 2),
#  ('吋', 2),
#  ('溶解', 2),
#  ('33', 2),
#  ('界', 2),
#  ('長壽', 2),
#  ('最佳', 2),
#  ('忘', 2),
#  ('衣服', 2),
#  ('放', 2),
#  ('手機', 2),
#  ('專家', 2),
#  ('形', 2),
#  ('人口', 2),
#  ('趨勢', 2),
#  ('建議', 2),
#  ('維護', 2),
#  ('加強', 2),
#  ('大蒜', 2),
#  ('強大', 2),
#  ('a', 2),
#  ('莎', 2),
#  ('包裝', 2),
#  ('年後', 2),
#  ('一個月', 2),
#  ('不見', 2),
#  ('蜂王漿', 2),
#  ('黑芝麻', 2),
#  ('抗腫瘤', 2),
#  ('體衰', 2),
#  ('傳染', 2),
#  ('傳染性', 2),
#  ('性肝炎', 2),
#  ('肝炎', 2),
#  ('補肝腎', 2),
#  ('肝腎', 2),
#  ('益精', 2),
#  ('精血', 2),
#  ('潤腸', 2),
#  ('頭暈眼花', 2),
#  ('眼花', 2),
#  ('耳聾', 2),
#  ('呼吸作用', 2),
#  ('心律', 2),
#  ('心律不整', 2),
#  ('減低', 2),
#  ('清洗', 2),
#  ('舒張', 2),
#  ('心肌梗塞', 2),
#  ('梗塞', 2),
#  ('腦萎縮', 2),
#  ('老年性', 2),
#  ('老年性癡呆', 2),
#  ('癡呆', 2),
#  ('抗壓', 2),
#  ('憂鬱症', 2),
#  ('失眠症', 2),
#  ('鍺', 2),
#  ('友善', 2),
#  ('米', 2),
#  ('1973', 2),
#  ('世界衛生', 2),
#  ('世界衛生組織', 2),
#  ('衛生', 2),
#  ('衛生組織', 2),
#  ('國發', 2),
#  ('發表', 2),
#  ('表報', 2),
#  ('極微', 2),
#  ('微量', 2),
#  ('微量元素', 2),
#  ('肝病', 2),
#  ('腎臟病', 2),
#  ('國人', 2),
#  ('瘋', 2),
#  ('加', 2),
#  ('中國', 2),
#  ('農村', 2),
#  ('農村居民', 2),
#  ('村居', 2),
#  ('居民', 2),
#  ('民營', 2),
#  ('食管', 2),
#  ('食管癌', 2),
#  ('肝糖', 2),
#  ('糖元', 2),
#  ('儲藏', 2),
#  ('細胞分裂', 2),
#  ('分裂', 2),
#  ('紅血', 2),
#  ('紅血球', 2),
#  ('深', 2),
#  ('主將', 2),
#  ('醣類', 2),
#  ('機', 2),
#  ('轉', 2),
#  ('研究成果', 2),
#  ('成果', 2),
#  ('妙', 2),
#  ('兒', 2),
#  ('發病率', 2),
#  ('抗生', 2),
#  ('抗生素', 2),
#  ('肺炎', 2),
#  ('醋', 2),
#  ('神器', 2),
#  ('性生理', 2),
#  ('不順', 2),
#  ('疲憊', 2),
#  ('窈窕', 2),
#  ('杏', 2),
#  ('內容', 2),
#  ('痔瘡', 2),
#  ('膽結石', 2),
#  ('銅', 2),
#  ('救星', 2),
#  ('極致', 2),
#  ('想', 2),
#  ('消耗', 2),
#  ('幫', 2),
#  ('乳房', 2),
#  ('雌激素', 2),
#  ('鬆鬆', 2),
#  ('下垂', 2),
#  ('乳', 2),
#  ('女', 2),
#  ('蓄積', 2),
#  ('善性', 2),
#  ('壯陽', 2),
#  ('中度', 2),
#  ('勃起', 2),
#  ('表現', 2),
#  ('破壞', 2),
#  ('明治', 2),
#  ('成長', 2),
#  ('排便', 2),
#  ('牛蒡', 2),
#  ('清', 2),
#  ('新生', 2),
#  ('防治', 2),
#  ('治', 2),
#  ('膽鹽', 2),
#  ('食物', 2),
#  ('降血糖', 2),
#  ('補腎', 2),
#  ('快樂', 2),
#  ('依賴', 2),
#  ('依賴症', 2),
#  ('證明', 2),
#  ('具', 2),
#  ('製', 2),
#  ('酚', 2),
#  ('免於', 2),
#  ('實', 2),
#  ('宮', 2),
#  ('內分', 2),
#  ('內分泌', 2),
#  ('生殖', 2),
#  ('達', 2),
#  ('色斑', 2),
#  ('E19', 2),
#  ('光線', 2),
#  ('潤', 2),
#  ('清晰', 2),
#  ('瑪', 2),
#  ('龍', 2),
#  ('0800', 2),
#  ('乳清', 2),
#  ('水平', 2),
#  ('不易', 2),
#  ('助燃', 2),
#  ('兩個', 2),
#  ('寶貝', 2),
#  ('胃腸', 2),
#  ('情況', 2),
#  ('專案', 2),
#  ('保留', 2),
#  ('宣稱', 2),
#  ('療效', 2),
#  ('97', 2),
#  ('四二', 2),
#  ('二頭', 2),
#  ('二頭肌', 2),
#  ('94', 2),
#  ('組織細胞', 2),
#  ('癒', 2),
#  ('雙層', 2),
#  ('指甲', 2),
#  ('對照', 2),
#  ('門診', 2),
#  ('精神', 2),
#  ('秒', 2),
#  ('妳', 2),
#  ('白皙', 2),
#  ('粗糙', 2),
#  ('尤其', 2),
#  ...]

# %%
font = r'msjh.ttc'
#想要文字雲出現的圖示
#mask = np.array(Image.open(r"mayday_mask.png"))
 
#其他參數請自行參考wordcloud
my_wordcloud = WordCloud(background_color="white",font_path=font,collocations=False, width=2400, height=2400, margin=1)  
my_wordcloud.generate_from_frequencies(frequencies=Counter(terms))
 
#產生圖片
plt.figure( figsize=(20,10), facecolor='k')
plt.imshow(my_wordcloud,interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad=0)
#顯示用
plt.show()
